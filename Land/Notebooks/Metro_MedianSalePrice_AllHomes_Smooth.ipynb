# %%
# Imports
import pandas as pd
import pyodbc
import sqlalchemy
from sqlalchemy import create_engine
import urllib
import numpy as np

# %% [markdown]
# df_backup = pd.read_csv("./Updates/STG_ZLLW_Metro_MedianSalePrice_AllHomes_Smooth.txt", sep = "\t")
# df_backup.to_csv("./Backups/STG_ZLLW_Metro_MedianSalePrice_AllHomes_Smooth.txt", sep="\t")

# %%
df = pd.read_csv("http://files.zillowstatic.com/research/public_v2/median_sale_price/Metro_median_sale_price_uc_SFRCondo_smoothed_month.csv")

# %%
df
# Out:
#      RegionID  SizeRank                          RegionName RegionType  \
# 0      102001         0                       United States    Country
# 1      394913         1                        New York, NY        Msa
# 2      753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3      394463         3                         Chicago, IL        Msa
# 4      394514         4               Dallas-Fort Worth, TX        Msa
# ..        ...       ...                                 ...        ...
# 116    394586       504                       Faribault, MN        Msa
# 117    394309       527                       Albemarle, NC        Msa
# 118    394742       595                       Kerrville, TX        Msa
# 119    395091       641                     Shelbyville, TN        Msa
# 120    395230       672                      Wilmington, OH        Msa
#
#     StateName  2008-04-30  2008-05-31  2008-06-30  2008-07-31  2008-08-31  \
# ...

# %%
# Filter to NC
df_nc = df[df["StateName"] == "NC"]

# %%
df_nc
# Out:
#      RegionID  SizeRank         RegionName RegionType StateName  2008-04-30  \
# 24     394458        24      Charlotte, NC        Msa        NC    174815.0
# 48     395012        48        Raleigh, NC        Msa        NC    197417.0
# 73     394648        73     Greensboro, NC        Msa        NC    140000.0
# 81     395235        81  Winston-Salem, NC        Msa        NC    135333.0
# 96     394549       104         Durham, NC        Msa        NC    195167.0
# 113    394546       343           Dunn, NC        Msa        NC    161833.0
# 117    394309       527      Albemarle, NC        Msa        NC    121917.0
#
#      2008-05-31  2008-06-30  2008-07-31  2008-08-31  ...  2019-11-30  \
# 24     175815.0    177083.0    181431.0    182764.0  ...    253083.0
# 48     200833.0    205667.0    211667.0    211583.0  ...    288833.0
# 73     140000.0    142667.0    143667.0    145167.0  ...    164667.0
# 81     138333.0    142272.0    145439.0    143772.0  ...    170667.0
# ...
